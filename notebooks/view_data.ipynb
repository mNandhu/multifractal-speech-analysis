# %%
# Show current path
import os
print(os.getcwd())
# Out:
# g:\Projects\multifractal-speech-analysis\notebooks

# %%
import sys
from pathlib import Path
sys.path.append("..")
from src.data import load_dataset_dataframe, PipelineOptions

# %%
opts = PipelineOptions(prefix=Path(".."))

df = load_dataset_dataframe(options=opts)
df.head()
# Out:
#                   sample_key duplicate_class_key recording_id speaker_id  \
# 0    healthy::1::vowels::a_h          healthy::1            1          1
# 1    healthy::1::vowels::a_l          healthy::1            1          1
# 2  healthy::1::vowels::a_lhl          healthy::1            1          1
# 3    healthy::1::vowels::a_n          healthy::1            1          1
# 4    healthy::1::vowels::i_h          healthy::1            1          1
#
#    is_overlap_speaker  is_overlap_speaker_id recording_type recording_date  \
# 0               False                  False              n     1997-11-20
# 1               False                  False              n     1997-11-20
# 2               False                  False              n     1997-11-20
# 3               False                  False              n     1997-11-20
# 4               False                  False              n     1997-11-20
#
#   birth_date sex  ... remarks_path has_remarks          recording_dir  \
# ...
